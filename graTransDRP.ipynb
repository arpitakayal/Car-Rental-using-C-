# %% [markdown]
# <a href="https://colab.research.google.com/github/arpitakayal/Car-Rental-using-C-/blob/main/graTransDRP.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/chuducthang77/GraTransDRP.git
# Out:
# Cloning into 'GraTransDRP'...
# remote: Enumerating objects: 125, done.
# remote: Counting objects: 100% (70/70), done.
# remote: Compressing objects: 100% (53/53), done.
# remote: Total 125 (delta 36), reused 49 (delta 17), pack-reused 55
# Receiving objects: 100% (125/125), 279.61 KiB | 1.44 MiB/s, done.
# Resolving deltas: 100% (69/69), done.

# %%
pip install pubchempy
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for pubchempy: filename=PubChemPy-1.0.4-py3-none-any.whl size=13820 sha256=3389844287e4b474ca4f818718dc222de86e7995d554daf472722b2d291d9692
#   Stored in directory: /root/.cache/pip/wheels/90/7c/45/18a0671e3c3316966ef7ed9ad2b3f3300a7e41d3421a44e799
# Successfully built pubchempy
# ...

# %%
pip install rdkit
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 34.9/34.9 MB 43.5 MB/s eta 0:00:00
# ...

# %%
pip install torch-geometric
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 4.5 MB/s eta 0:00:00
# ...

# %%
# %run /content/GraTransDRP/preprocess_mix.py --choice 0
# Out:
# preparing  GDSC_train.pt in pytorch format!
# Pre-processed data found: data/processed/GDSC_train_mix.pt, loading ...
# Pre-processed data found: data/processed/GDSC_val_mix.pt, loading ...
# Pre-processed data found: data/processed/GDSC_test_mix.pt, loading ...
# build data complete

# %%
# %run /content/GraTransDRP/training.py --model 0 --train_batch 1024 --val_batch 1024 --test_batch 1024 --lr 0.0001 --num_epoch 10 --log_interval 20 --cuda_name "cuda:0"
# Out:
# Learning rate:  0.0001
# Epochs:  10
#
# running on  GAT_GCN_Transformer_meth_ge_mut_GDSC
# Pre-processed data found: data/processed/GDSC_train_mix.pt, loading ...
# Pre-processed data found: data/processed/GDSC_val_mix.pt, loading ...
# Pre-processed data found: data/processed/GDSC_test_mix.pt, loading ...
# CPU/GPU:  False
# cpu
# /usr/local/lib/python3.10/dist-packages/torch_geometric/deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/transformer.py:306: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.batch_first was not True(use batch_first for better inference performance)
#   warnings.warn(f"enable_nested_tensor is True, but self.use_nested_tensor is False because {why_not_sparsity_fast_path}")
# Training on 3300 samples...

# %%
# %run /content/GraTransDRP/training.py --model 1 --train_batch 1024 --val_batch 1024 --test_batch 1024 --lr 0.0001 --num_epoch 4 --log_interval 20 --cuda_name "cuda:0"
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/IPython/core/magics/execution.py in run(self, parameter_s, runner, file_finder)
#     713             fpath = arg_lst[0]
# --> 714             filename = file_finder(fpath)
#     715         except IndexError:
#
# /usr/local/lib/python3.10/dist-packages/IPython/utils/path.py in get_py_filename(name, force_win32)
#     108     else:
# --> 109         raise IOError('File `%r` not found.' % name)
#     110
#
# OSError: File `'/content/GraTransDRP/training.py'` not found.
#
# During handling of the above exception, another exception occurred:
#
# Exception                                 Traceback (most recent call last)
# <ipython-input-1-08008db448b0> in <cell line: 1>()
# ...

# %%
# %run /content/GraTransDRP/training.py --model 2 --train_batch 1024 --val_batch 1024 --test_batch 1024 --lr 0.0001 --num_epoch 3 --log_interval 20 --cuda_name "cuda:0"
# Out:
# Learning rate:  0.0001
# Epochs:  3
#
# running on  GAT_GCN_Transformer_meth_GDSC
# Pre-processed data found: data/processed/GDSC_train_mix.pt, loading ...
# Pre-processed data found: data/processed/GDSC_val_mix.pt, loading ...
# Pre-processed data found: data/processed/GDSC_test_mix.pt, loading ...
# CPU/GPU:  True
# cuda:0
# Training on 5968 samples...
# Train epoch: 1 [0/5968 (0%)]	Loss: 0.080584
# Make prediction for 746 samples...
# Make prediction for 747 samples...
#  rmse improved at epoch  1 ; best_rmse: 0.07010720003876458 GAT_GCN_Transformer_meth GDSC
# Training on 5968 samples...
# Train epoch: 2 [0/5968 (0%)]	Loss: 0.067228
# Make prediction for 746 samples...
# Make prediction for 747 samples...
#  rmse improved at epoch  2 ; best_rmse: 0.06973748388696202 GAT_GCN_Transformer_meth GDSC
# Training on 5968 samples...
# Train epoch: 3 [0/5968 (0%)]	Loss: 0.070104
# Make prediction for 746 samples...
# Make prediction for 747 samples...
# ...

# %%
# %run /content/GraTransDRP/training.py --model 3 --train_batch 1024 --val_batch 1024 --test_batch 1024 --lr 0.0001 --num_epoch 3 --log_interval 20 --cuda_name "cuda:0"
# Out:
# Learning rate:  0.0001
# Epochs:  3
#
# running on  GAT_GCN_Transformer_meth_ge_GDSC
# Pre-processed data found: data/processed/GDSC_train_mix.pt, loading ...
# Pre-processed data found: data/processed/GDSC_val_mix.pt, loading ...
# Pre-processed data found: data/processed/GDSC_test_mix.pt, loading ...
# CPU/GPU:  True
# cuda:0
# Training on 472 samples...
# Train epoch: 1 [0/472 (0%)]	Loss: 0.075563
# Make prediction for 59 samples...
# Make prediction for 59 samples...
#  rmse improved at epoch  1 ; best_rmse: 0.06015624465880432 GAT_GCN_Transformer_meth_ge GDSC
# Training on 472 samples...
# Train epoch: 2 [0/472 (0%)]	Loss: 0.063902
# Make prediction for 59 samples...
# Make prediction for 59 samples...
#  rmse improved at epoch  2 ; best_rmse: 0.05586956596445979 GAT_GCN_Transformer_meth_ge GDSC
# Training on 472 samples...
# Train epoch: 3 [0/472 (0%)]	Loss: 0.059715
# Make prediction for 59 samples...
# Make prediction for 59 samples...
# ...

# %%
# %run /content/GraTransDRP/training.py --model 4 --train_batch 1024 --val_batch 1024 --test_batch 1024 --lr 0.0001 --num_epoch 3 --log_interval 20 --cuda_name "cuda:0"
# Out:
# Learning rate:  0.0001
# Epochs:  3
#
# running on  GAT_GCN_Transformer_ge_only_GDSC
# Pre-processed data found: data/processed/GDSC_train_mix.pt, loading ...
# Pre-processed data found: data/processed/GDSC_val_mix.pt, loading ...
# Pre-processed data found: data/processed/GDSC_test_mix.pt, loading ...
# CPU/GPU:  True
# cuda:0
# Training on 5968 samples...
# Train epoch: 1 [0/5968 (0%)]	Loss: 0.068898
# Make prediction for 746 samples...
# Make prediction for 747 samples...
#  rmse improved at epoch  1 ; best_rmse: 0.06969851068467249 GAT_GCN_Transformer_ge_only GDSC
# Training on 5968 samples...
# Train epoch: 2 [0/5968 (0%)]	Loss: 0.067089
# Make prediction for 746 samples...
# Make prediction for 747 samples...
#  rmse improved at epoch  2 ; best_rmse: 0.06910244485605521 GAT_GCN_Transformer_ge_only GDSC
# Training on 5968 samples...
# Train epoch: 3 [0/5968 (0%)]	Loss: 0.064906
# Make prediction for 746 samples...
# Make prediction for 747 samples...
# ...

# %%
# %run /content/GraTransDRP/training.py --model 5 --train_batch 1024 --val_batch 1024 --test_batch 1024 --lr 0.0001 --num_epoch 3 --log_interval 20 --cuda_name "cuda:0"
# Out:
# Learning rate:  0.0001
# Epochs:  3
#
# running on  GAT_GCN_Transformer_GDSC
# Pre-processed data found: data/processed/GDSC_train_mix.pt, loading ...
# Pre-processed data found: data/processed/GDSC_val_mix.pt, loading ...
# Pre-processed data found: data/processed/GDSC_test_mix.pt, loading ...
# CPU/GPU:  True
# cuda:0
# Training on 5968 samples...
# Train epoch: 1 [0/5968 (0%)]	Loss: 0.069021
# Make prediction for 746 samples...
# Make prediction for 747 samples...
#  rmse improved at epoch  1 ; best_rmse: 0.06924137194666562 GAT_GCN_Transformer GDSC
# Training on 5968 samples...
# Train epoch: 2 [0/5968 (0%)]	Loss: 0.066827
# Make prediction for 746 samples...
# Make prediction for 747 samples...
#  rmse improved at epoch  2 ; best_rmse: 0.06865389592897216 GAT_GCN_Transformer GDSC
# Training on 5968 samples...
# Train epoch: 3 [0/5968 (0%)]	Loss: 0.067094
# Make prediction for 746 samples...
# Make prediction for 747 samples...
# ...

# %%
# %run /content/GraTransDRP/training.py --model 6 --train_batch 1024 --val_batch 1024 --test_batch 1024 --lr 0.0001 --num_epoch 3 --log_interval 20 --cuda_name "cuda:0"
# Out:
# Learning rate:  0.0001
# Epochs:  3
#
# running on  GAT_GCN_Transformer_meth_only_GDSC
# Pre-processed data found: data/processed/GDSC_train_mix.pt, loading ...
# Pre-processed data found: data/processed/GDSC_val_mix.pt, loading ...
# Pre-processed data found: data/processed/GDSC_test_mix.pt, loading ...
# CPU/GPU:  True
# cuda:0
# Training on 5968 samples...
# Train epoch: 1 [0/5968 (0%)]	Loss: 0.071645
# Make prediction for 746 samples...
# Make prediction for 747 samples...
#  rmse improved at epoch  1 ; best_rmse: 0.0698205840225122 GAT_GCN_Transformer_meth_only GDSC
# Training on 5968 samples...
# Train epoch: 2 [0/5968 (0%)]	Loss: 0.066803
# Make prediction for 746 samples...
# Make prediction for 747 samples...
#  rmse improved at epoch  2 ; best_rmse: 0.06923545689061435 GAT_GCN_Transformer_meth_only GDSC
# Training on 5968 samples...
# Train epoch: 3 [0/5968 (0%)]	Loss: 0.067642
# Make prediction for 746 samples...
# Make prediction for 747 samples...
# ...

# %%
# %run /content/GraTransDRP/preprocess_blind_drug.py --choice 0
# Out:
# Streaming output truncated to the last 5000 lines.
# Converting SMILES to graph: 10864/15859
# Converting SMILES to graph: 10865/15859
# Converting SMILES to graph: 10866/15859
# Converting SMILES to graph: 10867/15859
# Converting SMILES to graph: 10868/15859
# Converting SMILES to graph: 10869/15859
# Converting SMILES to graph: 10870/15859
# Converting SMILES to graph: 10871/15859
# Converting SMILES to graph: 10872/15859
# Converting SMILES to graph: 10873/15859
# Converting SMILES to graph: 10874/15859
# Converting SMILES to graph: 10875/15859
# Converting SMILES to graph: 10876/15859
# Converting SMILES to graph: 10877/15859
# Converting SMILES to graph: 10878/15859
# Converting SMILES to graph: 10879/15859
# Converting SMILES to graph: 10880/15859
# Converting SMILES to graph: 10881/15859
# Converting SMILES to graph: 10882/15859
# Converting SMILES to graph: 10883/15859
# Converting SMILES to graph: 10884/15859
# Converting SMILES to graph: 10885/15859
# ...
